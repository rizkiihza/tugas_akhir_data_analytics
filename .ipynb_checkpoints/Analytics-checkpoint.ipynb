# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv("result_k.csv")
# df2 = pd.read_csv("result_size_2_generated.csv")
# df = pd.concat([df1, df2])
# df.index = [i+1 for i in range(len(df))]

dfs = []

for i in range(1, 8):
    dfs.append(pd.read_csv("result_size_limit/data_%d" % (i)))
df = pd.concat(dfs)
df.drop(['Unnamed: 0'], inplace=True, axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-acd1192feea9> in <module>
#       7
#       8 for i in range(1, 8):
# ----> 9     dfs.append(pd.read_csv("result_size_limit/data_%d" % (i)))
#      10 df = pd.concat(dfs)
#      11 df.drop(['Unnamed: 0'], inplace=True, axis=1)
#
# ...

# %%
sns.scatterplot(x='k', y='Time', data=df)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
y = np.atleast_2d(df['Time']).T
x = np.atleast_2d(df['k']).T

poly = PolynomialFeatures(degree=1)
x_transform = poly.fit_transform(x)

linearRegression = LinearRegression()
linearRegression.fit(x_transform, y)

coeff = linearRegression.coef_.T

result = linearRegression.predict(x_transform)

x_list = [val[0] for val in x]
result_list = [val[0] for val in result]
df_current = pd.DataFrame.from_dict({'x': x_list, 'y': result_list})

print(linearRegression.coef_)
print(linearRegression.intercept_)

sns.lineplot(x='x', y='y', data=df_current)
sns.scatterplot(x='k', y='Time', data=df, color="coral")
plt.show()
# Out:
# [[0.         6.91090146]]
# [722.13160055]

# %%
sns.scatterplot(x='neg_sup', y='Memory', data=df)
plt.show()

# %%
sns.scatterplot(x='neg_sup', y='Accuracy', data=df)
plt.show()

# %%
sns.distplot(df['Accuracy'], hist=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-24-7b3c1e8cce83> in <module>
# ----> 1 sns.distplot(df['Accuracy'], hist=False)
#       2 plt.show()
#
# ~/.local/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# ~/.local/lib/python3.6/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
# ...

# %%
sns.boxplot(df['Accuracy'])
plt.show()

# %%
df['Accuracy'].describe()

# %%
from scipy import stats

# %%
_, p = stats.normaltest(df['Accuracy'])
print("p-value is",p)
print("confidence is", 1-p)

# %%
x_bar = df['Accuracy'].mean()
x_std = df['Accuracy'].std()
x_n = len(df['Accuracy'])

confidence = 0.9
alpha = 1 - confidence
t_alpha_half = stats.t.ppf(1-(alpha/2), x_n - 1) 

delta = t_alpha_half * x_std / x_n
left_limit = x_bar - delta
right_limit = x_bar + delta

print(left_limit, right_limit)
